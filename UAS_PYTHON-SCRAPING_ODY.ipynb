# %%
from bs4 import BeautifulSoup as bs
import requests as req
import glob
import json
import os
import csv
import time

# Base URL and API URL for Bukalapak
baseurl = 'https://www.bukalapak.com/u/'
apiurl = 'https://api.bukalapak.com/stores/'

class Bukalapak:
    def __init__(self, username):
        self.username = username
        self.urltoko = baseurl + username
        self.headerbrowser = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:74.0) Gecko/20100101 Firefox/74.0'}

        # Send a GET request to the seller's page
        pg_data = req.get(self.urltoko, headers=self.headerbrowser, timeout=3000)
        try:
            if pg_data.status_code == 200:
                soup = bs(pg_data.text, 'html.parser')

                # Get the seller's ID
                print("[+] Mengambil id penjual ...")
                self.idseller = soup.find('a', attrs={'data-user-id': True})['data-user-id']
                print("[+] Id penjual: " + self.idseller)

                # Get the access token for the API
                print("[+] Mengambil access token ...")
                stoken = soup.find_all('script')
                gtoken = str(stoken[4]).replace("<script>localStorage.setItem('bl_token', '", "").replace(
                    "');</script>", "")
                gtoken = json.loads(gtoken)
                self.token = gtoken['access_token']
                print("[+] Access token: " + self.token)

                # Start grabbing the products
                self.grabproduk()
            else:
                print("[!] Username tidak ditemukan!")
        except Exception as e:
            print(e)
            print("[!] Website down!")
            exit()

    def grabproduk(self):
        print("=== GRABBING PRODUK ===")
        print("[+] Memulai download halaman produk ...")
        print("\x1B[3m" + "(delay 3 detik untuk menghindari anti-spam!)" + "\x1B[0m")

        # Get the total number of products from the API
        api = apiurl + str(self.idseller) + '/products?offset=0&limit=50&access_token=' + self.token
        total_product = req.get(api, headers=self.headerbrowser, timeout=3000).json()
        total = total_product['meta']['total']
        print("[+] Total produk: " + str(total))

        # Remove old files
        print("[+] Hapus file lama ...")
        if not os.path.exists("data"):
            os.makedirs("data")
        for filename in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            os.remove(filename)
        for filename in glob.glob(str(self.idseller) + "_bukalapak.csv"):
            os.remove(filename)

        # Grab each page of products
        a = 0
        b = 0
        while a < total and b < 1:
            print("-> download halaman ke-" + str(b + 1))
            api = apiurl + str(self.idseller) + '/products?offset=' + str(a) + '&limit=50&access_token=' + self.token
            pg_data = req.get(api, headers=self.headerbrowser, timeout=3000).json()

            # If there are no more products, break the loop
            if not pg_data['data']:
                break

            # Save the product data to a JSON file
            with open("data/" + str(self.idseller) + "_bukalapak" + str(b) + ".json", 'w') as json_file:
                json.dump(pg_data['data'], json_file)

            # Increment offsets and wait for 3 seconds to avoid anti-spam measures
            a += 50
            b += 1
            time.sleep(3)

        # Merge all JSON files into one
        print("[+] Merging data produk ...")
        data = []
        for f in glob.glob("data/" + str(self.idseller) + "_bukalapak*.json"):
            with open(f) as infile:
                data.extend(json.load(infile))
        with open("data/" + str(self.idseller) + "_bukalapak_all.json", 'w') as outfile:
            json.dump(data, outfile)

        # Create a CSV file with the product data
        print("[+] Membuat csv data produk ...")
        f_data = []
        for i in data:
            f_data.append([
    i['name'],
    i['price'],
    i['category']['name'],
    i.get('city', '')
])


        f_header = ['nama_produk', 'harga', 'kategori', 'kota']

        with open(str(self.idseller) + '_bukalapak.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(f_header)
            writer.writerows(f_data)

        print('selesai! ' + str(self.idseller) + '_bukalapak.csv')


sname = input("[+] Masukkan username seller: https://www.bukalapak.com/u/")
act = Bukalapak(sname)
# Out:
# [+] Masukkan username seller: https://www.bukalapak.com/u/timuray
# [+] Mengambil id penjual ...
# [+] Id penjual: 2895088
# [+] Mengambil access token ...
# [+] Access token: eyJhbGciOiJSUzI1NiIsImtpZCI6ImFjY291bnRzLmp3dC5hY2Nlc3MtdG9rZW4iLCJ0eXAiOiJKV1QifQ.....eQOn7MWE-fOS5Sw0oCFr-6HRRZJ2pGrnr9PN6bYi_uleC8cBhd9n2Amzu8qqS1GPw4fYR7kEiT4YhA9YO_3aTNTdQBqUpNPXDaWQK0GW3z0CQgk7yDhOCrRKOSUb_Bo_iIxAtxNs6wSj06vmxuqVeCCztrwCmcZQL0fAnPCXO6FnXk2Xe5gShP4h2XXTJ9YMIj7II0yRhpRPvMzzaymqprurVKr_OwiHNn3EgkRTxIuda_tMHxTFM_buUhdNn7jC6A8NdcXedcEFpgFFnSSDdGFmIVYTCUHR_YcdBeVkA-q4mkCbZmuaUgTOdH5lgqxMka7uYSBNppELxojOIjHK0w
# === GRABBING PRODUK ===
# [+] Memulai download halaman produk ...
# (delay 3 detik untuk menghindari anti-spam!)
# [+] Total produk: 764
# [+] Hapus file lama ...
# -> download halaman ke-1
# [+] Merging data produk ...
# [+] Membuat csv data produk ...
# selesai! 2895088_bukalapak.csv

# %%
import pandas as pd

# reading the database
data = pd.read_csv("2895088_bukalapak.csv")

# printing the top 52 rows
display(data.head(52))
# Out:
#                                           nama_produk   harga  \
# 0   Paddles Back Button Attachment Key Stick Stik ...  110000
# 1          Stick Stik Controller Gamepad PS2 TW Warna   31000
# 2   Kontrol Freek FPS Thumb Grip Analog Stik Stick...   59500
# 3   Kontrol Freek FPS Thumb Grip Karet Silikon Ana...   59500
# 4   Kontrol Freek FPS Thumb Grip Silikon Analog St...   59500
# 5   Kontrol Freek FPS Thumb Grip Karet Silikon Ana...   59500
# 6   Kontrol Freek Thumb Grip Silikon Analog Stik S...   59500
# 7   Topi Tutup Jamur Tombol Analog Stik Stick Xbox...    2400
# 8   Stik Stick Joystick Gamepad Xbox Series ONE PC...  300000
# 9   Rak Storage Stand Tempat Penyimpanan Disc Kase...  129000
# 10  Tas Airfoam Pouch Dompet Pocket Travel Bag Nin...   60000
# 11  Tas Airfoam Pouch Dompet Case Travel Bag Ninte...   60000
# 12  Batre Baterai Battery PSP Fat 1000 Stamina 180...   50000
# 13  Power Supply Mesin PS2 Fat Seri 5 5000X 50001 ...   50000
# 14  Tombol Analog Replacement Part PS Vita PSVita ...   37500
# 15  PS2 To HDMI Adapter Converter PS1 PS2 PS3 Ke H...   45000
# 16  Bluetooth USB 5.0 V5.0 CSR Mini Dongle Adapter...   26000
# 17  Silikon Silicone Karet Cover Case Pro Controll...   50000
# 18  Silikon Silicone Karet Cover Pro Controller Ni...   50000
# 19  Silikon Silicone Karet Cover Pro Controller Ni...   32000
# 20  Silikon Silicone Karet Cover Pro Controller Ni...   32000
# 21  Silikon Silicone Karet Cover Pro Controller Ni...   32000
# 22  Silikon Silicone Karet Cover Pro Controller Ni...   32000
# 23  Silikon Silicone Karet Cover Case Pro Controll...   32000
# 24  Charging Stand Dock Battery Baterai Batre Stic...  150000
# 25  Battery Pack Rechargeable Batre Baterai Stik S...   74000
# 26  Poke Ball Bag Tas Dompet Protective Tempat Sim...   29000
# 27  Microphone Mic Pro USB Universal PS4 PS5 Xbox ...   99000
# 28  Silikon Silicone Pelindung Karet Cover Nintend...   48000
# 29  Silikon Silicone Pelindung Karet Cover Nintend...   48000
# 30  Silikon Silicone Pelindung Karet Cover Nintend...   48000
# 31  Charging Pad Cooling Fan Kipas Hand Grip Ninte...  250000
# 32  Fanny Pack Tas Slempang Dompet Tempat Simpan N...  125000
# 33  Hand Grip Handle Stand Body Gagang Pegangan Ni...   95000
# 34  Pistol Tembakan Game Gun Shooting Handle Move ...  140000
# 35  Stick Stik Wireless Pro Controller Nintendo Sw...  163000
# 36  Stick Stik Wireless Pro Controller Nintendo Sw...  163000
# 37  Stick Stik Wireless Pro Controller Nintendo Sw...  163000
# 38  Stick Stik Wireless Pro Controller Nintendo Sw...  163000
# 39  Stick Stik Wireless Pro Controller Nintendo Sw...  163000
# 40  PXN V3 Pro Steering Wheel Racing Stir Setir Fo...  980000
# 41  PXN V3 Pro Steering Wheel Racing Stir Setir PS...  980000
# 42  Topi Jamur Tombol Analog Stik Stick PS2 PS3 Be...    1300
# 43  Vertical Vertikal Magic Stand Berdiri Dudukan ...   34500
# 44  Vertical Vertikal Magic Stand Berdiri Dudukan ...   38000
# 45  Wii Zapper Gun Shooting Pistol Nintendo Wii Re...   72500
# 46  Wiimote + Nunchuk Controller Build In Motion P...  200000
# 47  Wiimote + Nunchuk Controller Build In Motion P...  200000
# 48  Racing Wheel Stir Kemudi Mario Go Kart Steerin...   60000
# 49  2 Stik Stick Gamepad Joystick PS2 Original Pab...  115000
#
#               kategori  kota
# 0            Aksesoris   NaN
# 1   Joystick & Gamepad   NaN
# 2   Joystick & Gamepad   NaN
# 3   Joystick & Gamepad   NaN
# 4   Joystick & Gamepad   NaN
# 5   Joystick & Gamepad   NaN
# 6   Joystick & Gamepad   NaN
# 7   Joystick & Gamepad   NaN
# 8   Joystick & Gamepad   NaN
# 9            Aksesoris   NaN
# 10           Aksesoris   NaN
# 11           Aksesoris   NaN
# 12           Aksesoris   NaN
# 13           Aksesoris   NaN
# 14  Joystick & Gamepad   NaN
# 15           Aksesoris   NaN
# 16   Aksesoris Lainnya   NaN
# 17           Aksesoris   NaN
# 18           Aksesoris   NaN
# 19           Aksesoris   NaN
# 20           Aksesoris   NaN
# 21           Aksesoris   NaN
# 22           Aksesoris   NaN
# 23           Aksesoris   NaN
# 24           Aksesoris   NaN
# 25           Aksesoris   NaN
# 26           Aksesoris   NaN
# 27           Aksesoris   NaN
# 28           Aksesoris   NaN
# 29           Aksesoris   NaN
# 30           Aksesoris   NaN
# 31           Aksesoris   NaN
# 32           Aksesoris   NaN
# 33           Aksesoris   NaN
# 34           Aksesoris   NaN
# 35           Aksesoris   NaN
# 36           Aksesoris   NaN
# 37           Aksesoris   NaN
# 38           Aksesoris   NaN
# 39           Aksesoris   NaN
# 40           Aksesoris   NaN
# 41           Aksesoris   NaN
# 42  Joystick & Gamepad   NaN
# 43           Aksesoris   NaN
# 44           Aksesoris   NaN
# 45  Joystick & Gamepad   NaN
# 46  Joystick & Gamepad   NaN
# 47           Aksesoris   NaN
# 48           Aksesoris   NaN
# 49           Aksesoris   NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("2895088_bukalapak.csv")

# Selecting the first 50 data points
data_subset = data.head(52)

# Scatter plot with 'rating' against 'jumlah_rating'
plt.scatter(data_subset['harga'], data_subset['kategori'])

# Adding title to the plot
plt.title("Elektronik - Scatter Plot")

# Setting the x and y labels
plt.xlabel('harga')
plt.ylabel('kategori')

# Save the plot as a PNG file
plt.savefig('scatter_plot.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import pandas as pd # Digunakan untuk mengimpor modul Pandas ke dalam script.
import matplotlib.pyplot as plt # Digunakan untuk mengimpor modul Matplotlib ke dalam script.

# Digunakan untuk membaca file CSV dengan nama "data_aksesoris.csv".
data = pd.read_csv("2895088_bukalapak.csv")

# Digunakan untuk membuat sebuah figur baru dalam visualisasi dengan ukuran 12x7 inci.
plt.figure(figsize=(12, 7))

# Menghitung jumlah kemunculan tiap nilai dalam kolom 'Address'.
plt.hist(data['harga'])

# Menambahkan judul.
plt.title("Histogram Aksesoris Elektronik")

# Menyimpan Histogram dalam format JPG dengan nama file 'Histogram_Aksesoris.jpg'.
plt.savefig('Histogram_Aksesoris.jpg', dpi=300, bbox_inches='tight')

# Menampilkan hasil Histogram.
plt.show()

# %%
import pandas as pd # Digunakan untuk mengimpor modul Pandas ke dalam script.
import matplotlib.pyplot as plt # Digunakan untuk mengimpor modul Matplotlib ke dalam script.

# Digunakan untuk membaca file CSV dengan nama "data_aksesoris.csv".
data = pd.read_csv("2895088_bukalapak.csv")

# Digunakan untuk membuat sebuah figur baru dalam visualisasi dengan ukuran 12x7 inci.
plt.figure(figsize=(12, 7))

data['harga'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)  # Membuat pie chart dengan persen.
plt.ylabel('') # Menghapus label sumbu Y.

# Menambahkan judul.
plt.title("Pie Chart Aksesoris Elektronik")

# Menyimpan Pie Chart dalam format JPG dengan nama file 'PieChart_Aksesoris.jpg'.
plt.savefig('PieChart_Aksesoris1.jpg', dpi=300, bbox_inches='tight')

# Menampilkan hasil Pie Chart.
plt.show()
